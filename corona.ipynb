# %% [markdown]
# <a href="https://colab.research.google.com/github/Muasya0254/Data_Science/blob/main/corona.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv', header=None)

# %%
df.head()
# Out:
#              0          1                   2            3               4  \
# 0    longitude   latitude  housing_median_age  total_rooms  total_bedrooms
# 1  -114.310000  34.190000           15.000000  5612.000000     1283.000000
# 2  -114.470000  34.400000           19.000000  7650.000000     1901.000000
# 3  -114.560000  33.690000           17.000000   720.000000      174.000000
# 4  -114.570000  33.640000           14.000000  1501.000000      337.000000
#
#              5           6              7                   8
# 0   population  households  median_income  median_house_value
# 1  1015.000000  472.000000       1.493600        66900.000000
# 2  1129.000000  463.000000       1.820000        80100.000000
# 3   333.000000  117.000000       1.650900        85700.000000
# 4   515.000000  226.000000       3.191700        73400.000000

# %%
corona = pd.read_csv('/content/sample_data/corona_virus.csv', encoding='unicode_escape')

# %%
corona.head()
# Out:
#   Country,Other   Total Cases New Cases Total Deaths  New Deaths  \
# 0           USA  10,66,27,427       NaN    11,59,824         NaN
# 1         India   4,49,39,515       NaN     5,31,508         NaN
# 2        France   3,99,80,570       NaN     1,66,556         NaN
# 3       Germany   3,84,03,667       NaN     1,73,044         NaN
# 4        Brazil   3,74,49,418       NaN     7,01,494         NaN
#
#   Total Recovered New Recovered Active Cases Serious,Critical  \
# 0    10,45,49,551           NaN     9,18,052            1,368
# 1     4,43,56,693           NaN       51,314              NaN
# 2     3,96,77,000           NaN     1,37,014              869
# 3     3,81,92,900           600       37,723              NaN
# 4     3,62,49,161           NaN     4,98,763              NaN
#
#   Tot Cases/1M pop Deaths/1M pop     Total Tests Tests/1M pop      Population
# 0         3,18,476         3,464  1,17,68,34,935    35,14,983    33,48,05,269
# ...

# %%
# Make a request to the API
response = requests.get('https://api.unibit.ai/v2/stock/historical/?tickers=AAPL&accessKey=demo')

# Convert JSON response to DataFrame
data = pd.DataFrame(response.json())

# %%
data.head()
# Out:
#                                        meta_data result_data
# api_name               historical_stock_price_v2         NaN
# num_total_data_points                          1         NaN
# credit_cost                                   10         NaN
# start_date                             yesterday         NaN
# end_date                               yesterday         NaN

# %%
corona.describe()
# Out:
#        New Deaths
# count         2.0
# mean          3.0
# std           0.0
# min           3.0
# 25%           3.0
# 50%           3.0
# 75%           3.0
# max           3.0

# %%
corona.tail()
# Out:
#       Country,Other   Total Cases New Cases Total Deaths  New Deaths  \
# 227    Vatican City            29       NaN          NaN         NaN
# 228  Western Sahara            10       NaN            1         NaN
# 229      MS Zaandam             9       NaN            2         NaN
# 230         Tokelau             5       NaN          NaN         NaN
# 231          Total:  68,70,21,745    14,511    68,63,517         3.0
#
#     Total Recovered New Recovered Active Cases Serious,Critical  \
# 227              29           NaN            0              NaN
# 228               9           NaN            0              NaN
# 229               7           NaN            0              NaN
# 230             NaN           NaN            5              NaN
# 231    65,95,52,126        20,724  2,06,06,102           39,292
#
#     Tot Cases/1M pop Deaths/1M pop Total Tests Tests/1M pop Population
# 227           36,295           NaN         NaN          NaN        799
# ...
