# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# imaginary data
subjects = ['Math', 'Science', 'English', 'History']
scores = [85, 90, 75, 80]

# %%
# Create a DataFrame with subjects and scores
data = {'Subjects': subjects, 'Scores': scores}
df = pd.DataFrame(data)

# %%
# Create a bar plot using Seaborn
plt.figure(figsize=(10, 20))
sns.barplot(data=df, x='Subjects', y='Scores')
plt.title('Student Scores in Different Subjects')
plt.xlabel('Subjects')
plt.ylabel('Scores')
plt.show()

# %%
diamonds = sns.load_dataset('diamonds')

# %%
# Create a bar plot using Seaborn
plt.figure(figsize=(10, 8))
sns.scatterplot(data=diamonds, x='carat', y='price', size=None, style=None, hue='cut')
plt.title('Diamonds')
plt.xlabel('carat')
plt.ylabel('price')
plt.show()
